# %% [markdown]
# Lecture 2 : Machine Learning Pipelines

# %% [markdown]
# Problem Definition
#
#     ↓
#
# Data Collection
#
#     ↓
#
# Data Cleaning
#
#     ↓
#
# Exploratory Data Analysis (EDA)
#
#     ↓
#
# Feature Engineering
#
#     ↓
#
# Model Training
#
#     ↓
#
# Model Evaluation
#
#     ↓
#
# Model Deployment
